# %% [markdown]
# <a href="https://colab.research.google.com/github/SharonEstivalez/Introduction-to-Data-Science-in-Python/blob/main/C1_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Parte A**
# Find a list of all of all of the names in the following string using regex.

# %%
import re
def names():
    simple_string = """Amy is 5 years old, and her sister Mary is 2 years old.
    Ruth and Peter, their parents, have 3 kids."""

    # YOUR CODE HERE
    list0=re.findall("[A-Z]+[a-z]*",simple_string)
    return list0

print(names())
    #raise NotImplementedError()
# Out:
# ['Amy', 'Mary', 'Ruth', 'Peter']

# %%
assert len(names()) == 4, "There are four names in the simple_string"

# %% [markdown]
# ## **Parte B**
# The dataset file in [assets/grades.txt](assets/grades.txt) contains a line separated list of people with their grade in a class. Create a regex to generate a list of just those students who received a B in the course.

# %%
import re
def grades():
    with open ("/content/grades.txt", "r") as file:
        grades = file.read()

    # YOUR CODE HERE
    list1=re.findall("([A-Z]+[a-z]* [A-Z]+[a-z]*)\: B",grades)
    return list1
print(grades())
    #raise NotImplementedError()
# Out:
# ['Bell Kassulke', 'Simon Loidl', 'Elias Jovanovic', 'Hakim Botros', 'Emilie Lorentsen', 'Jake Wood', 'Fatemeh Akhtar', 'Kim Weston', 'Yasmin Dar', 'Viswamitra Upandhye', 'Killian Kaufman', 'Elwood Page', 'Elodie Booker', 'Adnan Chen', 'Hank Spinka', 'Hannah Bayer']

# %%
assert len(grades()) == 16

# %% [markdown]
# ## **Part C**
# Consider the standard web log file in [assets/logdata.txt](assets/logdata.txt). This file records the access a user makes when visiting a web page (like this one!). Each line of the log has the following items:
#
# * a host (e.g., '146.204.224.152')
# * a user_name (e.g., 'feest6811' **note: sometimes the user name is missing! In this case, use '-' as the value for the username.**)
# * the time a request was made (e.g., '21/Jun/2019:15:45:24 -0700')
# * the post request type (e.g., 'POST /incentivize HTTP/1.1' **note: not everything is a POST!**)
#
# Your task is to convert this into a list of dictionaries, where each dictionary looks like the following:
# ```
# example_dict = {"host":"146.204.224.152",
#                 "user_name":"feest6811",
#                 "time":"21/Jun/2019:15:45:24 -0700",
#                 "request":"POST /incentivize HTTP/1.1"}
# ```

# %%
#from typing import Pattern
import re
def logs():
    with open("/content/logdata.txt", "r") as file:
        logdata = file.read()
    # YOUR CODE HERE
    logd = re.findall('([\d+\.]+\d+) - ([a-z-*]+\d*) \[(.*)\] \"(.*)\"',logdata)
                         #0#host       #1#user_name   #2#time  #3#request
    list3 = []
    for i in logd:
        list3.append({'host': i[0],'user_name': i[1],'time': i[2],'request': i[3]})
    return list3
    raise NotImplementedError()
len(logs())
# Out:
# 979

# %%
assert len(logs()) == 979

one_item={'host': '146.204.224.152',
  'user_name': 'feest6811',
  'time': '21/Jun/2019:15:45:24 -0700',
  'request': 'POST /incentivize HTTP/1.1'}
assert one_item in logs(), "Sorry, this item should be in the log results, check your formating"
